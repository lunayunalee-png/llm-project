# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# Load processed dataset

# %%
import pandas as pd

df = pd.read_csv("../data/adobe_style_campaign_data.csv")

metrics = (
    df.groupby("campaign_name")
    .agg({
        "impressions": "sum",
        "clicks": "sum",
        "conversions": "sum",
        "revenue": "sum",
        "spend": "sum",
    })
    .reset_index()
)

# Derived correctly-weighted metrics
metrics["ctr"] = metrics["clicks"] / metrics["impressions"]
metrics["cvr"] = metrics["conversions"] / metrics["clicks"]
metrics["roas"] = metrics["revenue"] / metrics["spend"]
metrics.head()
# Out:
#   campaign_name  impressions   clicks  conversions       revenue  \
# 0    Campaign 1     34689697  1551423       266259  1.878866e+07
# 1   Campaign 10     39508953  1771647       311139  2.172607e+07
# 2    Campaign 2     35079079  1575930       275353  1.935095e+07
# 3    Campaign 3     35284468  1565588       278841  1.979419e+07
# 4    Campaign 4     33219928  1503726       261574  1.853453e+07
#
#           spend       ctr       cvr       roas
# 0  1.801393e+06  0.044723  0.171622  10.430071
# 1  2.036928e+06  0.044842  0.175621  10.666098
# 2  1.803419e+06  0.044925  0.174724  10.730148
# 3  1.795664e+06  0.044370  0.178106  11.023328
# 4  1.723585e+06  0.045266  0.173951  10.753471

# %% [markdown]
# Preepare metrics for LLM input

# %%
records = metrics.to_dict(orient="records")
records[0]
# Out:
# {'campaign_name': 'Campaign 1',
#  'impressions': 34689697,
#  'clicks': 1551423,
#  'conversions': 266259,
#  'revenue': 18788658.27321354,
#  'spend': 1801393.1107573558,
#  'ctr': 0.04472287549816304,
#  'cvr': 0.17162243952809775,
#  'roas': 10.430071127181265}

# %% [markdown]
# Build prompt templates

# %%
def build_summary_prompt(metrics):
    return f"""
You are an analytics assistant.

Given the campaign performance metrics below, generate 4-6 clear insights.
Discuss trends, funnel issues, anomalies, and recommended optimizations.

Metrics:
{metrics}
"""

# %%
def build_funnel_prompt(metrics):
    return f"""
Analyze the funnel for this campaign. Identify the largest drop-offs and explain why they might happen.

Use the data below:
{metrics}
"""

# %%
def build_anomaly_prompt(metrics, anomaly):
    return f"""
Anomaly detected: {anomaly}

Explain:
1. What probably caused it  
2. How it impacts performance  
3. What actions should be taken next  

Metrics:
{metrics}
"""

# %% [markdown]
# Generate insights with LLM

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.13/site-packages (2.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.13/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/lib/python3.13/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Call OpenAI LLM

from openai import OpenAI
client = OpenAI()

def generate_insight(metric_row):
    prompt = build_summary_prompt(metric_row)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %% [markdown]
# Apply insights to every campaign

# %%
metrics["llm_insight"] = metrics.apply(lambda row: generate_insight(row.to_dict()), axis=1)
metrics.head()
# Out:
#   campaign_name  impressions   clicks  conversions       revenue  \
# 0    Campaign 1     34689697  1551423       266259  1.878866e+07
# 1   Campaign 10     39508953  1771647       311139  2.172607e+07
# 2    Campaign 2     35079079  1575930       275353  1.935095e+07
# 3    Campaign 3     35284468  1565588       278841  1.979419e+07
# 4    Campaign 4     33219928  1503726       261574  1.853453e+07
#
#           spend       ctr       cvr       roas  \
# 0  1.801393e+06  0.044723  0.171622  10.430071
# 1  2.036928e+06  0.044842  0.175621  10.666098
# 2  1.803419e+06  0.044925  0.174724  10.730148
# 3  1.795664e+06  0.044370  0.178106  11.023328
# 4  1.723585e+06  0.045266  0.173951  10.753471
#
#                                          llm_insight
# 0  Based on the performance metrics provided for ...
# 1  Based on the provided campaign performance met...
# 2  Based on the provided campaign performance met...
# 3  Based on the provided performance metrics for ...
# 4  Here are several insights and observations der...

# %%
print(metrics.loc[0, "llm_insight"])
# Out:
# Based on the performance metrics provided for **Campaign 1**, here are 4-6 insights, along with discussions on trends, funnel issues, anomalies, and recommended optimizations:
#
# ### 1. Strong Return on Ad Spend (ROAS)
# - **Insight:** The campaign delivered a **ROAS of 10.43**, indicating for every dollar spent, the campaign generated over $10 in revenue.
# - **Recommendation:** Given the high ROAS, it is advisable to consider scaling this campaign. Increasing the budget could help capture more market share and drive additional revenue while maintaining efficiency.
#
# ### 2. High Click-Through Rate (CTR) but Moderate Conversion Rate (CVR)
# - **Insight:** The **CTR of 4.47%** suggests that the campaign's creative and targeting effectively attract user interest and drive clicks. However, the **CVR of 17.16%** indicates that while many users click on the ad, a relatively smaller proportion of those are converting to sales.
# - **Recommendation:** Investigate the post-click experience. This may involve optimizing the landing page, enhancing the user journey, or refining the targeting. Look into A/B testing different pages or offers to improve conversion effectiveness.
#
# ### 3. Impressive Volume with Room for Improvement
# - **Insight:** The campaign had **34,689,697 impressions** leading to **1,551,423 clicks** and **266,259 conversions**. While the volume of clicks and conversions is robust, the ratio of clicks to conversions (CVR) signals potential funnel inefficiencies.
# - **Recommendation:** Conduct a detailed analysis of user behavior on the landing page. Analyze drop-off points using tools like heat maps or session recordings to identify barriers to conversions and optimize the user experience accordingly.
#
# ### 4. Revenue and Spend Balance
# - **Insight:** The campaign generated **$18,788,658.27** in revenue against a spend of **$1,801,393.11**, which indicates a healthy profit margin. However, it is essential to examine the sustainability of this trend.
# - **Recommendation:** Monitor ongoing spend closely to ensure scaling does not compromise efficiency. Use historical data to create a predictive model to project future revenue and adjust the spend accordingly.
#
# ### 5. Potential Loss of Opportunities
# - **Insight:** While the campaign shows strong overall performance, the relatively low conversion rate suggests that there may be a significant number of lost opportunities. If 1,551,423 users clicked through but only 266,259 converted, there’s a large drop-off.
# - **Recommendation:** Implement retargeting strategies to re-engage users who clicked but did not convert. This could include email follow-ups, dynamic ads, or personalized offers to encourage a second visit.
#
# ### 6. Evaluate Audience Targeting
# - **Insight:** The high number of impressions suggests that the campaign is reaching a broad audience. While this can be beneficial, it may also mean the targeting isn’t optimal if conversion rates remain low.
# - **Recommendation:** Review audience segmentation and refine targeting strategies. This could involve creating more focused segments based on user demographics, interests, or behaviors to improve overall CVR.
#
# ### Summary
# Overall, **Campaign 1** demonstrates strong performance metrics like high ROAS and CTR but reveals areas for improvement in conversion rates. Focusing on optimizing the conversion path, enhancing targeting strategies, and leveraging retargeting tactics can further elevate campaign outcomes. Regularly monitoring these metrics will help in making data-informed decisions to drive continuous improvements.

# %% [markdown]
# Evaluate Hallucinations

# %%
def check_alignment(text, metrics):
    issues = []
    for key, value in metrics.items():
        if isinstance(value, (int, float)) and str(value)[:4] not in text:
            issues.append(key)
    return issues

metrics["quality_check"] = metrics.apply(lambda row: check_alignment(row["llm_insight"], row.to_dict()), axis=1)

# %%
metrics[["campaign_name", "llm_insight", "quality_check"]].head()
# Out:
#   campaign_name                                        llm_insight  \
# 0    Campaign 1  Based on the performance metrics provided for ...
# 1   Campaign 10  Based on the provided campaign performance met...
# 2    Campaign 2  Based on the provided campaign performance met...
# 3    Campaign 3  Based on the provided performance metrics for ...
# 4    Campaign 4  Here are several insights and observations der...
#
#                                        quality_check
# 0  [impressions, clicks, conversions, revenue, sp...
# 1  [impressions, clicks, conversions, revenue, sp...
# 2  [impressions, clicks, conversions, revenue, sp...
# 3  [impressions, clicks, conversions, revenue, sp...
# 4  [impressions, clicks, conversions, revenue, sp...

# %%
print(metrics.loc[0, "quality_check"])
# Out:
# ['impressions', 'clicks', 'conversions', 'revenue', 'spend', 'ctr', 'cvr']
